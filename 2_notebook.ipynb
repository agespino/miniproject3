# %% [markdown]
# # Problem 2

# %% [markdown]
# In this Jupyter notebook, we visualize how HMMs work. This visualization corresponds to problem 2 in set 6.
#
# Assuming your HMM module is complete and saved at the correct location, you can simply run all cells in the notebook without modification.

# %%
import os
import numpy as np
from IPython.display import HTML

from HMM import *
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    sample_sentence,
    visualize_sparsities,
    animate_emission
)

# %% [markdown]
# ## Visualization of the dataset

# %% [markdown]
# We will be using the Constitution as our dataset. First, we visualize the entirety of the Constitution as a wordcloud:

# %%
text = open(os.path.join(os.getcwd(), 'data/shakespeare.txt')).read()
wordcloud = text_to_wordcloud(text, title='Shakespear Sonnets')

# %% [markdown]
# ## Training an HMM

# %% [markdown]
# Now we train an HMM on our dataset. We use 10 hidden states and train over 100 iterations:

# %%
obs, obs_map = parse_observations(text)
A = np.loadtxt('HMM_A.txt')
O = np.loadtxt('HMM_O.txt')

HMM = HiddenMarkovModel(A, O)

# %% [markdown]
# ## Part G: Visualization of the sparsities of A and O

# %% [markdown]
# We can visualize the sparsities of the A and O matrices by treating the matrix entries as intensity values and showing them as images. What patterns do you notice?

# %%
visualize_sparsities(HMM, O_max_cols=50)

# %% [markdown]
# ## Generating a sample sentence

# %% [markdown]
# As you have already seen, an HMM can be used to generate sample sequences based on the given dataset. Run the cell below to show a sample sentence based on the Constitution.

# %% [markdown]
# ## Part H: Using varying numbers of hidden states

# %% [markdown]
# Using different numbers of hidden states can lead to different behaviours in the HMMs. Below, we train several HMMs with 1, 2, 4, and 16 hidden states, respectively. What do you notice about their emissions? How do these emissions compare to the emission above?

# %% [markdown]
# ## Part I: Visualizing the wordcloud of each state

# %% [markdown]
# Below, we visualize each state as a wordcloud by sampling a large emission from the state:

# %%
wordclouds = states_to_wordclouds(HMM, obs_map)

# %% [markdown]
# ## Visualizing the process of an HMM generating an emission

# %% [markdown]
# The visualization below shows how an HMM generates an emission. Each state is shown as a wordcloud on the plot, and transition probabilities between the states are shown as arrows. The darker an arrow, the higher the transition probability.
#
# At every frame, a transition is taken and an observation is emitted from the new state. A red arrow indicates that the transition was just taken. If a transition stays at the same state, it is represented as an arrowhead on top of that state.
#
# Use fullscreen for a better view of the process.

# %%
anim = animate_emission(HMM, obs_map, M=8)
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     131     try:
# --> 132         rgba = _colors_full_map.cache[c, alpha]
#     133     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ((-2.220446049250313e-16, -2.220446049250313e-16, -2.220446049250313e-16), None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5d3d899b12b1> in <module>()
# ----> 1 anim = animate_emission(HMM, obs_map, M=8)
#       2 HTML(anim.to_html5_video())
#
# ~/Desktop/cs155/miniproject3/HMM_helper.py in animate_emission(hmm, obs_map, M, height, width, delay)
#     290                                  color=(1 - hmm.A[i][j], ) * 3,
#     291                                  head_width=arrow_size, head_length=arrow_size,
# --> 292                                  zorder=int(hmm.A[i][j] * zorder_mult))
#     293             else:
#     294                 arrow = ax.arrow(x_i, y_i, 0, 0,
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in arrow(self, x, y, dx, dy, **kwargs)
#    4621         dy = self.convert_yunits(dy)
#    4622
# -> 4623         a = mpatches.FancyArrow(x, y, dx, dy, **kwargs)
#    4624         self.add_artist(a)
#    4625         return a
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/patches.py in __init__(self, x, y, dx, dy, width, length_includes_head, head_width, head_length, shape, overhang, head_starts_at_zero, **kwargs)
#    1288             verts = np.dot(coords, M) + (x + dx, y + dy)
#    1289
# -> 1290         Polygon.__init__(self, list(map(tuple, verts)), closed=True, **kwargs)
#    1291
#    1292
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/patches.py in __init__(self, xy, closed, **kwargs)
#     949
#     950         """
# --> 951         Patch.__init__(self, **kwargs)
#     952         self._closed = closed
#     953         self.set_xy(xy)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#     121                 warnings.warn("Setting the 'color' property will override"
#     122                               "the edgecolor or facecolor properties. ")
# --> 123             self.set_color(color)
#     124         else:
#     125             self.set_edgecolor(edgecolor)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/patches.py in set_color(self, c)
#     349                For setting the edge or face color individually.
#     350         """
# --> 351         self.set_facecolor(c)
#     352         self.set_edgecolor(c)
#     353
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/patches.py in set_facecolor(self, color)
#     332         """
#     333         self._original_facecolor = color
# --> 334         self._set_facecolor(color)
#     335
#     336     def set_fc(self, color):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/patches.py in _set_facecolor(self, color)
#     322             color = mpl.rcParams['patch.facecolor']
#     323         alpha = self._alpha if self._fill else 0
# --> 324         self._facecolor = colors.to_rgba(color, alpha)
#     325         self.stale = True
#     326
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     132         rgba = _colors_full_map.cache[c, alpha]
#     133     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 134         rgba = _to_rgba_no_colorcycle(c, alpha)
#     135         try:
#     136             _colors_full_map.cache[c, alpha] = rgba
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     193         c = c[:3] + (alpha,)
#     194     if any(elem < 0 or elem > 1 for elem in c):
# --> 195         raise ValueError("RGBA values should be within 0-1 range")
#     196     return c
#     197
#
# ValueError: RGBA values should be within 0-1 range
